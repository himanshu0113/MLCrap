# %%
import os
import os.path
import argparse
from sklearn.manifold import TSNE
import h5py

"""
parser = argparse.ArgumentParser()
parser.add_argument("--data", type = str  )
parser.add_argument("--plots_save_dir", type = str  )

args = parser.parse_args()
"""
# Load the test data
def load_h5py(filename):
	with h5py.File(filename, 'r') as hf:
		X = hf['X'][:]
		Y = hf['Y'][:]
	return X, Y

X, Y = load_h5py("Data/part_A_train.h5")

#X_tsne1 = TSNE(n_components=2, perplexity=5, learning_rate=10, n_iter=5000).fit_transform(X)
#X_tsne2 = TSNE(n_components=2, perplexity=25, learning_rate=10, n_iter=5000).fit_transform(X)
X_tsne3 = TSNE(n_components=3, perplexity=100, learning_rate=10, n_iter=4000).fit_transform(X)

# %%
print Y[0,:].tolist().index(1)
# Out:
# 4

# %%
colorset=['red','orange','pink','green','black','gray','blue','brown','yellow','cyan']
color=[]
for row in Y:
    pos = row.tolist().index(1)
    color.append(colorset[pos])

# %%
import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_tsne[:, 0], X_tsne[:, 1], X_tsne[:, 2], c = color)

#plt.subplot(1,3,1)
#plt.scatter(X_tsne1[:, 0], X_tsne1[:, 1], c = color)
#plt.subplot(1,3,2)
#plt.scatter(X_tsne2[:, 0], X_tsne2[:, 1], c = color)
#plt.subplot(1,3,3)
#plt.scatter(X_tsne3[:, 0], X_tsne3[:, 1], c = color)

# %%
plt.show()
